# %%
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision import transforms

# Root directory for the dataset
data_root = tfds.image.CelebA
# Spatial size of training images, images are resized to this size.
image_size = 64
# batch size
batch_size = 10

transform=transforms.Compose([
                              transforms.Resize(image_size),
                              transforms.CenterCrop(image_size),
                              transforms.ToTensor(),
                              transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
                              ])

dataset = ImageFolder(data_root, transform)

data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True, num_workers=8, drop_last=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c0fd83d5fd8c> in <module>()
#       4
#       5 # Root directory for the dataset
# ----> 6 data_root = tfds.image.CelebA
#       7 # Spatial size of training images, images are resized to this size.
#       8 image_size = 64
#
# AttributeError: module 'tensorflow_datasets.public_api' has no attribute 'image'

# %%
import tensorflow as tf

import tensorflow_datasets.public_api as tfds

# %%
from tensorflow_datasets.public_api import image.celeba
# Out:
#   File "<ipython-input-8-28502b1ae317>", line 1
#     from tensorflow_datasets.public_api import image.celeba
#                                                     ^
# SyntaxError: invalid syntax
