# %%
from tensorflow import keras
import numpy as np
path = keras.utils.get_file('nietzsche.txt',
                            origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 614400/600901 [==============================] - 1s 2us/step
# Corpus length: 600893

# %%
maxlen = 60
step = 3

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 31s 17ms/step - loss: 1.9871
# --- Generating with seed: "rtheless, a consolation. such pains are birth pains. the but"
# ------ temperature: 0.2
# rtheless, a consolation. such pains are birth pains. the but the still man a most the stand that the stand that is the still that the presention of the stand that is the stand the present that the sensition of the stand that is the stand of the manter and the possible of the stand that the still the constions of the still the still that is the still the sense of the still the philosophers that is the man that a stand that the still the still the philosophy------ temperature: 0.5
# the man that a stand that the still the still the philosophy called destition of the lation than this is only denders and man the period more than the same as the sture in the made that of the destility but that a whold a action of the science of the dears that the semicioning indelied that consension of the mantion and been and the from the most deemons of the spation of the stand thing at something moral been constions delinged and the most previldent co------ temperature: 1.0
# ing moral been constions delinged and the most previldent conthing of the conth for the philosophy bel agusult for un than e=toins fronged:--has bres to tendity,
# indsplantation of subtrumage
# highous. all
# every demenic our powical through must amour notivery matis-it
# from menm for his other yet opererfity for not to hest that ably the very beethered be accationap:s himself problen of simper.worty
# from his our at regaring of still foor eyes that formother ba------ temperature: 1.2
# rom his our at regaring of still foor eyes that formother bat culls altpaccary ;o this acquilation--that the
# themsels su1k and many
# to acxuction
# of purk, uran: what will
# mert of bating
# tho surituationing shquejzion of f-fecte limes: really
# moy
#
# purely
#  how tho
# ethopals of it
# ksavingance fr2etatidity: which caum.
#
# cloming opan, if that thal fearedes stult a goor do patsificad and subm-an,eacee of falios, kirftion one
# demideation with it:
#  langement,
#
# k nowepoch 2
# 1565/1565 [==============================] - 29s 18ms/step - loss: 1.6192
# --- Generating with seed: "d dwarfing of man to an absolutely
# gregarious animal (or as "
# ------ temperature: 0.2
# d dwarfing of man to an absolutely
# gregarious animal (or as the most string the same a such a moral such as the sensitions of the personal and such as the moral such a most carn of the same a strung and the consideration of the sense of the string to the pressupe and the sense of the consect of the same the same and strucition of the can the strange of the consection of the sense of the same a string to pressialic men the contemplation of the sense of the ------ temperature: 0.5
# ing to pressialic men the contemplation of the sense of the discineding and themselves to his to must stoon it has state of germans, so the decide and interpress of the beare of the most self intermanituting to discention of all and truth and like the subtlity of the sense of race, the science of such as the belief to the self-allows and the pressiatists of pured into the polite the explaise to the more has philosophy, but the perhaps
# who again to the does------ temperature: 1.0
# e more has philosophy, but the perhaps
# who again to the does resslizing who is medele: effect to thens to theacrety--honess it easies contempos, in create this andity his ceptory:
# class as we is to
# our estimentagediun-lats with certain grofle,
# which instantity realize and operate to super-ated
# and juddmanly from hammenned into lover and begrages interity to knew landaried philosopher, which worke thus anothers works it foliatrment, indifferent with them o------ temperature: 1.2
#  thus anothers works it foliatrment, indifferent with them ols: treass--sup and stuctmant (far the adpirst
# duality-wicking a strim. discontact, man bloffi, or edor, piltyory, floesive of distenefuls remails ning, with ferrectic
# daw ytredaluaks mialod: "premack, )o mankieng whaceny, a thing prentre,"
# whan preach
# whene, what
# tom. has "p"--me" nae, the firmismes! the subling,
# enterm, to respis varsa, lear upon thus and cos hing; they innectiantion in umind,
# eepoch 3
# 1565/1565 [==============================] - 26s 16ms/step - loss: 1.5257
# --- Generating with seed: "se of
# every impression of light and color made upon it. here"
# ------ temperature: 0.2
# se of
# every impression of light and color made upon it. here and the same the sense of the ancient the souls the same the are of the antiment the sense of the sense of the sense of the same the same something and the moral and the same for the seems of the sense of the sense the sense of the seems the same of the same the same the the same the same called the same the same the same of the same the same the such a self-consequently the same the sense of the------ temperature: 0.5
#  same the such a self-consequently the same the sense of the same the sanfer all as a compare for the antime of the moral should he been the same and all the souls of the constate which i hare and inservation, and in every learned to morality not as a wait in the sare of the precisely the same the same to the same of the weal however and allen the constance of the strength and the existence as a creater the moral summer of the such a critic same the will i------ temperature: 1.0
# reater the moral summer of the such a critic same the will in it
#
#   the errore fitherred humaniacly to
# science: in ond denation, the earny exhaled, come howed, these good when the man
# inducht. pricimed, or an explation, the eword of oluration, in the conceive him with encitives who regard, are would now in ethicy in
# ell bound and , belongn, endilation, without
# caste. bating, resectnous parine if
# taie of music
# soul in domanssverdom sovearrly their buld ovi------ temperature: 1.2
# taie of music
# soul in domanssverdom sovearrly their buld ovistledes, as there-famty: jostm of the , calvehymens--a day throhbolated folly
# to at constation to they
# other nation, "is necessumi, reflestionncion
# such arrourid the moyals were all ctill." dairnnever, heist. be critable
# 1,free to
# securage, when have
# creptholidaty, deceptionsful depresemennded has of-durdring the man, is case, upin cumplery of only (sacrity,t-worte. the
# "name typele,
# inten the ageepoch 4
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.4797
# --- Generating with seed: "ll faith
# collapses. what happens to the christian who compar"
# ------ temperature: 0.2
# ll faith
# collapses. what happens to the christian who comparing of the sense of the present the sense of the sense of the sense of the comparing the most profound and self-consequently and allow has a serve of the sense of the same the sense of the sense of the expression of the strength the sense of the sense of the sense of the sense of a profound the instinct of the sense of the same state of the last self-refunce and the most strength the same and call------ temperature: 0.5
# he last self-refunce and the most strength the same and called be for the sensition of conscience of the conscience of sense and man is its ade self-christian the some there are word the deceed of imphentant as in
# the compalse the sense and although of a companied in the eye with our of the companists of the distingual even the strength the destanding the aged all with with himself, the propersion in the them religion and cally subject deled to the profoun------ temperature: 1.0
#  in the them religion and cally subject deled to the profound was noight aw betwere-sing first retardedled his
# hist." in gol-ilited in beeeful, in god, the
# old was things treth there is it aims.
#
# ; suaded invervent of
# strong, not e
#  sole indued suspectably and sorage and
# were strong at : he pul an alters by indegeduent of all mearnise rite, in the can menness. and of makes and selfers are work, and through
# we circum sshare nameed by the new will not
# fare w------ temperature: 1.2
# d through
# we circum sshare nameed by the new will not
# fare when every tragic
# ood, thereby means--requirality: like ade rightces even have seems by ashaca; they are deled to two taik"--would "halsen everyy
# thar lant, myselves thata. i have neess to i the
# fame. thach firstuer."    in
# invensetted
# auded payimy at anotherselvest, opinity" in the, and not notrits feel" (and redivers boov. be ni in the more later rave things be inusuants of wantingrant!"--them weepoch 5
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.4476
# --- Generating with seed: "s possible: but this is impossible.
# economy in the use of bl"
# ------ temperature: 0.2
# s possible: but this is impossible.
# economy in the use of blast the senses of the sense of the stronger of the sense of the sense of the discourse of the senses of the world of the same the sense of the senses of the man is and the most seems to the sense of the same the senses of the sense of the senses of the sense of the sense of the same and the sense of the compulsing the most same and self to the sense of the sense of the sense of the sense of the st------ temperature: 0.5
# o the sense of the sense of the sense of the sense of the state of the same with a same at the and things is not so the essentially sensused it is to be all the truth of the comprofon and all the soulf even in the belief the and worst of all the truth of the father is to the seese with the proposition of the most nature of distrust for the command, it with the the mother of the subld and consequent to the false in the existence of the comprehates of the fi------ temperature: 1.0
# t to the false in the existence of the comprehates of the finers, a cause of the virgule, with roundly operation up which
# this equation of that an oldinationuaried feeling, the truehses haid--the ent, in the most
# other to much to its, his own
# stall to  on the computeless that one
# must appyertion are their thesetorous
# actainy nothing and counts at advantances as another imains vigouled moraliadidies from
# the novly
# stupicis of the love, have inevitova, this ------ temperature: 1.2
# s from
# the novly
# stupicis of the love, have inevitova, this ?tiatic
# bring, and alodig, sicencien? does nyothefue wishes tome
# more, so guns
# and siscesm,
# the very someary and oy individuus for the detacn,
# which amother, that
# knowlly
# vetut as all wicked, who
# egen-mexila valurs.
#
# inning, its
# defrect
# now that theoon one, to has indeed that bo, the contrir as is falses,
#
# min. "the
# up
# to mennest,
# the lapterineitia man not "twoul my
# pleasure, there , be voiquning,epoch 6
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.4271
# --- Generating with seed: "he is to him an evidence that strife does not
# always rage bu"
# ------ temperature: 0.2
# he is to him an evidence that strife does not
# always rage but the sense of the more man would be a serve of the man of the strong of the exception of the same world are be all the sense of the sense of the more as the sense of the same still to be a sense of the sense of the same as it is to the sense of the man of the man was the more there is a something to the more of the personal words as the streat of the strong of the same will is to the present man ------ temperature: 0.5
# streat of the strong of the same will is to the present man on the world of the spirit of comprehend itself of proper and to the more purely, at the proyest man was works of spirits who the animal super of a mankinds of man as deceptions for such understood and self-reaches of the
# world, and in the man were conscious orespice of the instinct and the constinct and ruration of war will always to the prodestification of the such the world ward of the germans ------ temperature: 1.0
#  prodestification of the such the world ward of the germans for emotical onle where be kedring" acce, and in arrangea, at a sercome spoble nithoy and other require mean ithlow only into gain
# words, is every diverous cosedujgulyned," the will to continuation from
# hostys
# voions, learns. a distreist to consersal
# the wreatingment above also has to do nitt=es shina,    very
# motilike--operates, the great ass to reyeal
# redast, presecting true, the signome in the ------ temperature: 1.2
# t ass to reyeal
# redast, presecting true, the signome in the blo,
# intermanarger" endounal greatng too--inerprebed a he asnay dotkns, at a crongur
# they are conditioned mescational danger, in overy toward, just as becoused
# emprosable be
# univone: the
# free spast our exsembiguded. any
# vasited, most of any, "dim, to whishe to a anywemet unnes-faculfed )eefting" sychong and know weake"--no pun; was the bor untimbe"nesss are madeal aim in what it, i belief to this epoch 7
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.4108
# --- Generating with seed: "en one's eyes;
# one ought at last to learn impatience, in ord"
# ------ temperature: 0.2
# en one's eyes;
# one ought at last to learn impatience, in order to the life and an an an a man is a soul and the strong of the conceptions of the sense of the conception of the more and also the german the same the religious artists and a soul and the same the problem and the sense of the same a soul in the sense of the same the religious and the first of the same the strong of the contradint of the promise of the same strong and conceptions of the concepti------ temperature: 0.5
# e promise of the same strong and conceptions of the conception of the tall not have no longer that they no longer of an invented its be a to the strength and morality which
# has had in their prograted in the free spirits of the senses of the being and senselous to be because of the "formulity and heart in the conceptions of the very reason of the conceptions of the more of a standporicism the place and the beredes and sense and hat to be wholong for
# the con------ temperature: 1.0
#  and the beredes and sense and hat to be wholong for
# the concterd fillcause has they, without surs. motiliant.
#
# iragation and thing were the own reaponal inveive to the often for dirty of a to things of german
#  of that hell, of it poin for their tear to be time its by shide of finally deeds. i mentic to sleeptume that stome against from its science and sourts of germand: this be an self-are dignance to cothers and experience a have doot that deveright--in ------ temperature: 1.2
# ce to cothers and experience a have doot that deveright--in "let
# conitutly.=-
#
# hoingtwors; becautic-pained: evil and philosophys"is are antwative,
# knowil
# endow drublely which, them
# coally
# firgied,
# in pain of
# titherd this question.
#
# lon at let frogh, one trained carrewite, yousge men of attairary its oth in it. but there is also thereofis suffering the nature, man for the general concentate powerfulhisate histain
# of premited she become which, their simples epoch 8
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.3975
# --- Generating with seed: "
# "think" is the predicate and is conditioned--to think is an"
# ------ temperature: 0.2
#
# "think" is the predicate and is conditioned--to think is any only the constant the problem of the same the sense of the same the subtle of the profound of the subtle conception of the most distented some the predinning of the fact of the problem of a man is always and intellection and more the fact of the master of the same all the same the religions of the present of the most profound the conceptions of the problem of the religion of the same who has dee------ temperature: 0.5
# tions of the problem of the religion of the same who has deeped in the submit of the disclose the
# same succent the conceptive the
# same legition of the most bad and an and personal means in the german place and receives of the longess of his fear, the sense of the french and developed and entille, with the fact and the deeper with the same the formed of the heart of such as the discloses of the transfriction and permits of the temple developer entiren, the ------ temperature: 1.0
# nsfriction and permits of the temple developer entiren, the asters and sensate or disturbaning, earsel good again upon a feater truthmanitice to here.
# verication in coningly as .=--who firsted the subject would not indeed something its will art which perhapering;
# it spenge mistarily un"quenturance are let an laws, that
# the
# truth andar ever li-. modern lead and patehood finally disduration is pile,
# necestanty tos.. no plays it
# whed kecioustiticient the pro------ temperature: 1.2
#
# necestanty tos.. no plays it
# whed kecioustiticient the prollnous to and prise
# ol, that of mirany" and a(mo nop light.
#
#
# eo
# te) impontaz,
# desires
# and there is to-depth1y, obsinaty, and his human.--thosul
# is were ourselves in
# tood echowe, guisable progressring noblent? a loftygra, are
# dencemence or lactily, his ourb trogar, has
# non-theures," for more p parrradid.
# fo preach indivinus and condections youturgjming to are, now to truth and
# sumctupinage and greepoch 9
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.3841
# --- Generating with seed: "requently,
# as has been hinted, that a scientific head is pla"
# ------ temperature: 0.2
# requently,
# as has been hinted, that a scientific head is place that the present discovered and man are the sense of the sense of the same the presenting of the most present spirits in the present discovered and the experience of the sense of the sense of a such a sense of the present says and the same strong when they will to the sensible of the same strong and the man is the condition of the condition of the sense of the conscience of the sense of the sam------ temperature: 0.5
# ition of the sense of the conscience of the sense of the same word of the word and but he look and schopines and morality of a constant other and great and progress and uncondition.
#
#
# 11.
#
# itage and the strong that is the contrary and among the best or conception, as in the most conscience of the
# most beliefces, and the east and misthre. and the value of the present one is a strength of the promise is the sense of mankind and ethic as in the
# schilar great ------ temperature: 1.0
# e is the sense of mankind and ethic as in the
# schilar great present man
# in the "errors, if, the insvicu: a samenish hand-was the great of the elseis of human a vasies of right and by rank, mhality, with the "libequestion to long that li-so demandicting winderness and squigation, even unbetwary runtly inconsequently, into last smeaking
# without asce opinion. moreover it is plebeing in to go unfliems and thing in older riceties and possessily but perfacted an------ temperature: 1.2
#  and thing in older riceties and possessily but perfacted and youn growary himself, posticute," ih the in
# xessibiltiws of also the
# pleasureish
# moar will under, falsouily as testoughal: one in their sacrifice; by untybion armuss. sty sovientainie, have mabition in ildies owe cy always, as our sight a late on opinions, and unfeeted and wiure, and his percouncts ol-into the greet enough ay hable-: ze
# one anakernest intendocable
# hearitical, from the victy of hepoch 10
# 1565/1565 [==============================] - 32s 21ms/step - loss: 1.3755
# --- Generating with seed: "s,
# as well as the course of our whole lives. no one knows to"
# ------ temperature: 0.2
# s,
# as well as the course of our whole lives. no one knows to the sense of the strength and the intellect the science of the instinct of the religious individually and the sense of the sense of the experience of the sense of the superiority of the strength and the standance of the sense of the strength of the spirit are stinds and the spirit and the spirit are still the sense of the experience of the states of the standance of the strength and sense of the ------ temperature: 0.5
# he states of the standance of the strength and sense of the most depth of the stooe spiritually to the soul the contempt of the expecting of the expection of the jest as a great partious contradiction in the conditionan, the man and such seems a soul speaks and more almost all the past and it is the sense of a manifold and christian something depths which a sense of the other had so distingutation to be should it is the expression of the european contempt ------ temperature: 1.0
#  to be should it is the expression of the european contempt of
# seeasion in the neble. are neces our to som, i a spirits in
# its vanifacants among the slapes napsocial hibximation. qui veething had towards without
# antiqco any
# hoal great "i discentually, errorsy, employ and but bieer cipilate litttes you: the states of
# sponder cacepas,
# we have hit believe--becometime.." all best case
# higher all sunsivered to the mild as soul, as it is should rengraid. the sha------ temperature: 1.2
# vered to the mild as soul, as it is should rengraid. the sharf birds os call!--be. the task of the moss at
# proficive the philosophy as
# the religion habits, mank? as more,
# toithever" wors, and
# onithets
# it it is atarcigation, who not newors, besidaliance a
