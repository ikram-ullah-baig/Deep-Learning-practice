# %%
num_validation_samples =10000

np.random.shuffle(data) #shuflling the data is usually appropriate

validation_data = dat[:num_validation_samples] #define validation the set
data = data[num_validation_samples:]

training_data = data[:] #define the training set

model = get_model() #train a model on the trainig data, and evaluate it on
model.train(training_data)#the validation data
validation_score = model.evaluate(validation_data)

#at this point you can tune your model,
#retrain it, evaluate it, tune it again. . .

model = get_model()
model.train(no.concatenate([training_data, validation_data]))
test_score = model.evaluate(test_data)
