# %%
import tensorflow
from tensorflow.keras.datasets import CelebA
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-74152a909f22> in <module>()
#       1 import tensorflow
# ----> 2 from tensorflow.keras.datasets import CelebA
#
# ImportError: cannot import name 'CelebA' from 'tensorflow.keras.datasets' (/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/datasets/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
